# %%
import pickle 
# import torch 
import numpy
import matplotlib.pyplot as plt

# %%
with open("../pkl_files/sample_states.pkl", "rb") as f:
    save_dict = pickle.load(f)

# %%
save_dict["state_hist"][0].keys()
# Out:
# odict_keys(['sensor', 'auxiliary_sensor', 'task_obs', 'depth'])

# %%
plt.imshow(save_dict["state_hist"][0]['depth'])

# %%
save_dict["state_hist"][0]["sensor"].shape
# Out:
# (6,)

# %%
import numpy as np
np.sort(save_dict["state"][0]["task_obs"])
# Out:
# array([-3.98067398e+01, -8.81133366e+00, -1.00032961e+00, -1.00022626e+00,
#        -1.00008941e+00, -9.26857591e-01, -8.93702984e-01, -8.26942861e-01,
#        -6.55641779e-01, -5.18415928e-01, -5.11174321e-01, -3.89402157e-01,
#        -2.33437344e-01, -2.33201414e-01, -2.02597544e-01, -1.43825993e-01,
#        -1.33482069e-01, -3.52384821e-02, -3.22933346e-02, -5.99306075e-03,
#        -5.99306075e-03, -1.97050543e-03, -1.97050543e-03, -1.13925652e-03,
#        -7.81289593e-04, -4.15071565e-04, -3.44369018e-04, -1.42130053e-04,
#         1.37945751e-04,  2.24292101e-04,  3.22938870e-04,  4.72855850e-04,
#         1.64925849e-03,  9.76890884e-03,  3.97497863e-02,  4.57217842e-02,
#         5.33112250e-02,  5.87611534e-02,  6.88779876e-02,  8.18804279e-02,
#         8.94886553e-02,  9.77285436e-02,  1.74351409e-01,  1.76689625e-01,
#         3.84320050e-01,  3.85215122e-01,  3.90532672e-01,  4.00813282e-01,
#         4.43405122e-01,  5.72307706e-01,  6.14311039e-01,  7.41821289e-01,
#         7.43862212e-01,  7.53598988e-01,  9.00916877e-01,  9.00916877e-01,
#         9.42346513e-01,  9.49375689e-01,  1.28109539e+00,  3.73139811e+00])

# %%
plt.imshow(save_dict["state"][850]["rgb"])

# %%
plt.imshow(save_dict["state"][865]["depth"])

# %%
save_dict["state"][850]["task_obs"]
# Out:
# array([1.10889183, 0.49541798, 0.35578877, 0.09971234, 0.63001004,
#        0.79187026, 0.39026453, 1.01760925])

# %%
save_dict.keys()
# Out:
# dict_keys(['state', 'reward', 'done_hist', 'info_hist'])

# %%
plt.plot(save_dict["reward"])
