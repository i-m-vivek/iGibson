# %%
import pickle 
import torch 
import numpy
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /home/vkmittal14/WORKSPACE/TUD/vk_igibson/iGibson/igibson_usage/notebooks

# %%
with open("/home/vkmittal14/WORKSPACE/TUD/vk_igibson/iGibson/igibson_usage/jr_interactive_nav_states.pkl", "rb") as f:
    save_dict = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-7-6bd230c5c9a5> in <module>
#       1 with open("/home/vkmittal14/WORKSPACE/TUD/vk_igibson/iGibson/igibson_usage/jr_interactive_nav_states.pkl", "rb") as f:
# ----> 2     save_dict = pickle.load(f)
#
# EOFError: Ran out of input

# %%
save_dict["state_hist"][0].keys()
# Out:
# odict_keys(['task_obs', 'rgb', 'depth', 'scan'])

# %%
save_dict["state_hist"][0]["scan"]

# %%
plt.imshow(save_dict["state_hist"][0]["rgb"])

# %%
plt.imshow(save_dict["state_hist"][0]["depth"])

# %%
save_dict["state_hist"][0]["task_obs"]
# Out:
# array([ 2.37816837, -0.70312132, -0.03074556, -0.30340827])
